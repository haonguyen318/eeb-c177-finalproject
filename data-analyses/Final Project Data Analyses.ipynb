# %%
pwd
# Out:
# '/home/eebc177student/Developer/repos/eeb-c177-finalproject/data-analyses'

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/home/eebc177student/Downloads/Mussel_Filtration.csv")
data
# Out:
#     Mussels  Trial Treatment  Mussel  Mass (g)  Size Length (mm)  \
# 0       1.0    1.0         A     1.0      70.0             81.03
# 1       2.0    1.0         A     2.0      89.4             90.68
# 2       3.0    1.0         A     3.0     105.0             88.33
# 3       4.0    1.0         B     1.0      78.1             86.00
# 4       5.0    1.0         B     2.0      87.1             86.27
# ..      ...    ...       ...     ...       ...               ...
# 56      NaN    NaN       NaN     NaN       NaN               NaN
# 57      NaN    NaN       NaN     NaN       NaN               NaN
# 58      NaN    NaN       NaN     NaN       NaN               NaN
# 59      NaN    NaN       NaN     NaN       NaN               NaN
# 60      NaN    NaN       NaN     NaN       NaN               NaN
#
#     Size Width (mm)  Size Height (mm)  Total mass (g)  Average mass (g)
# 0             35.86             32.73             NaN               NaN
# ...
