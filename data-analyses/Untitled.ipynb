# %%
import file1 as fl 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
co2_df = fl.create_dataframe()
co2_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Developer/repos/eeb-c177-finalproject/data-analyses/file1.py in create_dataframe()
#      36     try:
# ---> 37         return pd.read_csv(filename, parse_dates=['dt'])
#      38     except:
#
# ...
